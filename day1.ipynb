# %%
print("Welcome to the bootcamp!")
# Out:
# Welcome to the bootcamp!

# %%
2+2
# Out:
# 4

# %% [markdown]
# # This is a markdown cell

# %%
#code cells are for python

# %%
3+4
# Out:
# 7

# %%
10*5
# Out:
# 50

# %%
100/4
# Out:
# 25.0

# %%
favorite_number = 5

# %%
favorite_number
# Out:
# 5

# %%
favorite_number+10
# Out:
# 15

# %%
#if you restart the kernel, all variables will be reset, and favorite_number will not be defined

# %%
#restart run all can clean up your code if you get confused/out of order

# %%
name = "Eva"
food = "strawberries"
print(name + "likes" + food + "!")
# Out:
# Evalikesstrawberries!

# %%
print(name, "likes", food + "!")
# Out:
# Eva likes strawberries!

# %% [markdown]
# # in markdown you can add...
# ## subheadings

# %%
numbers = [1,2,3,4]
for n in numbers:
    print(n)
# Out:
# 1
# 2
# 3
# 4
